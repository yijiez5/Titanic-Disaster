# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train=pd.read_csv('train.csv')

# %%
df_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %%
total=df_train.isnull().sum().sort_values(ascending=False)
percent=(df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=['Total','Percent'])
missing_data
# Out:
#              Total   Percent
# Cabin          687  0.771044
# Age            177  0.198653
# Embarked         2  0.002245
# PassengerId      0  0.000000
# Survived         0  0.000000
# Pclass           0  0.000000
# Name             0  0.000000
# Sex              0  0.000000
# SibSp            0  0.000000
# Parch            0  0.000000
# Ticket           0  0.000000
# Fare             0  0.000000

# %%
#data exploration

# %%
#Cabin
df_train['CabinBool']=df_train['Cabin'].isnull().astype('int')
df_train['CabinBool']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    1
# 889    0
# 890    1
# Name: CabinBool, Length: 891, dtype: int64

# %%
sns.barplot(x='CabinBool',y='Survived',data=df_train)

print('percentage of cabinbool=0 who survived:', df_train['Survived'][df_train['CabinBool']==0].value_counts(normalize=True)[1]*100)
print('percentage of cabinbool=1 who survived:', df_train['Survived'][df_train['CabinBool']==1].value_counts(normalize=True)[1]*100)
# Out:
# percentage of cabinbool=0 who survived: 66.66666666666666
# percentage of cabinbool=1 who survived: 29.985443959243085

# %%
#Age
labels=['unknown','baby','child','teenager','young adult','adult','senior']
bins=[-5,0,4,13,18,30,60,np.inf]
df_train['Age']=df_train['Age'].fillna(-1)
df_train['AgeGroup']=pd.cut(df_train['Age'],bins,labels=labels)
sns.barplot(x='AgeGroup',y='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='AgeGroup', ylabel='Survived'>

# %%
#Embarked
sns.barplot(x='Embarked',y='Survived',data=df_train)
print('percentage of embarked=S who survived:',df_train['Survived'][df_train['Embarked']=='S'].value_counts(normalize=True)[1]*100)
print('percentage of embarked=C who survived:',df_train['Survived'][df_train['Embarked']=='C'].value_counts(normalize=True)[1]*100)
print('percentage of embarked=Q who survived:',df_train['Survived'][df_train['Embarked']=='Q'].value_counts(normalize=True)[1]*100)
# Out:
# percentage of embarked=S who survived: 33.69565217391305
# percentage of embarked=C who survived: 55.35714285714286
# percentage of embarked=Q who survived: 38.961038961038966

# %%
#Pclass
sns.barplot(x='Pclass',y='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
#sex
sns.barplot(x='Sex',y='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
#SibSp
sns.barplot(x='SibSp',y='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
#Parch
sns.barplot(x='Parch',y='Survived',data=df_train)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %%
#data cleaning

# %%
df_train=df_train.drop(['Cabin'],axis=1)

# %%
df_train=df_train.drop(['Ticket'],axis=1)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Embarked', 'CabinBool', 'AgeGroup'],
#       dtype='object')

# %%
df_train['Title']=df_train.Name.str.extract(' ([A-Za-z]+)\.',expand=False)
pd.crosstab(df_train['Title'],df_train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
df_train['Title']=df_train['Title'].replace(['Capt','Col','Countess','Don','Dr','Jonkheer','Major','Master','Rev'],'Rare')
df_train['Title']=df_train['Title'].replace(['Mlle','Lady','Ms'],'Miss')
df_train['Title']=df_train['Title'].replace('Mme','Mrs')
df_train['Title']=df_train['Title'].replace('Sir','Mr')
df_train[['Title','Survived']].groupby(['Title'],as_index=False).mean()
# Out:
#   Title  Survived
# 0  Miss  0.704301
# 1    Mr  0.158301
# 2   Mrs  0.793651
# 3  Rare  0.475410

# %%
title_mapping={'Rare':1,'Miss':2,'Mrs':3,'Mr':4}
df_train['Title']=df_train['Title'].map(title_mapping)
df_train['Title']=df_train['Title'].fillna(0)

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  -1.0      0
# ...

# %%
rare_age=df_train[df_train['Title']==1]['AgeGroup'].mode()
rare_age
# Out:
# 0    baby
# Name: AgeGroup, dtype: category
# Categories (7, object): ['unknown' < 'baby' < 'child' < 'teenager' < 'young adult' < 'adult' < 'senior']

# %%
miss_age=df_train[df_train['Title']==2]['AgeGroup'].mode()
miss_age
# Out:
# 0    young adult
# Name: AgeGroup, dtype: category
# Categories (7, object): ['unknown' < 'baby' < 'child' < 'teenager' < 'young adult' < 'adult' < 'senior']

# %%
mrs_age=df_train[df_train['Title']==3]['AgeGroup'].mode()
mrs_age
# Out:
# 0    adult
# Name: AgeGroup, dtype: category
# Categories (7, object): ['unknown' < 'baby' < 'child' < 'teenager' < 'young adult' < 'adult' < 'senior']

# %%
mr_age=df_train[df_train['Title']==4]['AgeGroup'].mode()
mr_age
# Out:
# 0    young adult
# Name: AgeGroup, dtype: category
# Categories (7, object): ['unknown' < 'baby' < 'child' < 'teenager' < 'young adult' < 'adult' < 'senior']

# %%
age_title_mapping = {1: 'baby', 2: 'young adult', 3: 'adult', 4: 'young adult'}

# %%
for x in range(len(df_train['AgeGroup'])):
    if df_train['AgeGroup'][x]=='unknown':
        df_train['AgeGroup'][x]=age_title_mapping[df_train['Title'][x]]

# %%
df_train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
age_mapping = {'baby': 1, 'child': 2, 'teenager': 3, 'young adult': 4, 'adult': 5, 'senior': 6}
df_train['AgeGroup'] = df_train['AgeGroup'].map(age_mapping)

# %%
df_train=df_train.drop(['Age'],axis=1)

# %%
df_train=df_train.drop(['Name'],axis=1)

# %%
sex_mapping={'male':1,'female':0}
df_train['Sex']=df_train['Sex'].map(sex_mapping)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  \
# 0            1         0       3    1      1      0   7.2500        S
# 1            2         1       1    0      1      0  71.2833        C
# 2            3         1       3    0      0      0   7.9250        S
# 3            4         1       1    0      1      0  53.1000        S
# 4            5         0       3    1      0      0   8.0500        S
#
#    CabinBool  AgeGroup  Title
# 0          1       4.0      4
# 1          0       5.0      3
# 2          1       4.0      2
# 3          0       5.0      3
# 4          1       5.0      4

# %%
embarked_mapping={'S':0,'C':1,'Q':2}
df_train['Embarked']=df_train['Embarked'].map(embarked_mapping)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    1      1      0   7.2500       0.0
# 1            2         1       1    0      1      0  71.2833       1.0
# 2            3         1       3    0      0      0   7.9250       0.0
# 3            4         1       1    0      1      0  53.1000       0.0
# 4            5         0       3    1      0      0   8.0500       0.0
#
#    CabinBool  AgeGroup  Title
# 0          1       4.0      4
# 1          0       5.0      3
# 2          1       4.0      2
# 3          0       5.0      3
# 4          1       5.0      4

# %%
df_train['FareBand']=pd.qcut(df_train['Fare'],4,labels=[1,2,3,4])
df_train=df_train.drop(['Fare'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fare'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch  Embarked  CabinBool  \
# 0            1         0       3    1      1      0       0.0          1
# 1            2         1       1    0      1      0       1.0          0
# 2            3         1       3    0      0      0       0.0          1
# 3            4         1       1    0      1      0       0.0          0
# 4            5         0       3    1      0      0       0.0          1
#
#    AgeGroup  Title FareBand
# 0       4.0      4        1
# 1       5.0      3        4
# 2       4.0      2        2
# 3       5.0      3        4
# 4       5.0      4        2
